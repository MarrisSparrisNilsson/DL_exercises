# %%
# %matplotlib notebook
import numpy as np
from IPython.display import HTML, display
import time

# %%
import perceptron

# %%
# Generate the data
data = perceptron.generate_data()

# %%
# Plot the data
plt = perceptron.Plot()
plt.plot_data(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt = perceptron.Plot()
# Initialize perceptron
weights = np.matrix([0,0,0]).T
eta = 0.5

# Run learning
for instance in data:
    plt.plot_data(data, weights)
    if np.sign(instance[0, 0:3]*weights) != instance[0,3]:
        weights = weights + eta* (instance[0,3]*instance[0,0:3]).T
        time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">
