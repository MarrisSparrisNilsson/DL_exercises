# %% [markdown]
# ### Calculate total video lecture time

# %%
# ------- ML --------
# Ensemble Models
# listOfMinutes = [2.52, 11.42, 7.41, 8.08, 8.54, 44.03, 38.37] 

# Unsupervised Learning
# listOfMinutes = [4.44, 29.55, 23.25, 22.52, 23.23]

# Time Series
# listOfMinutes = [1.29, 11.15, 15.40, 31.33, 11.49, 3.02, 13.20]


# ------- DL --------

# 0 - Neural Networks 101
listOfMinutes0 = [0.51, 7.53, 17.01, 8.40, 15.53, 13.11, 26.51, 11.16]

# 2 - Training Neural Networks
listOfMinutes2 = [2.02, 9.22, 20.33, 12.31, 17.42, 26.33, 9.03, 38.51]

# 3 - Convolutional Neural Networks
listOfMinutes3 = [0.44, 29.50, 13.46, 18.55, 7.49, 26.51]

# 4 - Recurrent Neural Network and Attention
listOfMinutes4 = [6.15, 14.02, 21.57, 29.56, 13.56, 14.58]

# 5 - Transformers and Large Language Models
listOfMinutes5 = [19.39, 28.06, 32.14]

# 6 - Explainable Deep Learning
listOfMinutes6 = [1.56, 7.49, 18.44, 18.52, 10.57, 13.23]

# 7 - Deep Learning on Graphs
listOfMinutes7 = [1.54, 10.53, 20.19, 23.49, 18.24]

# 8 - Generative Models
listOfMinutes8 = [6.38, 12.30, 13.52, 14.13, 7.58, 21.08, 32.16]

# 11 - Computer Vision
listOfMinutes11 = [7.14, 7.44, 3.19, 12.59, 29.22, 13.38, 14.08]

# 12 - Neuro-Symbolic Reasoning
listOfMinutes12 = [12.28, 23.38, 8.59, 30.13, 8.34]

# 13 - Evaluation
listOfMinutes13 = [4.52, 10.55, 24.59, 23.58, 20.01, 18.41, 9.59]

all_lectures = [
    listOfMinutes0,
    listOfMinutes2,
    listOfMinutes3,
    listOfMinutes4,
    listOfMinutes5,
    listOfMinutes6,
    listOfMinutes7,
    listOfMinutes8,
    listOfMinutes11,
    listOfMinutes12,
    listOfMinutes13
]

total_time = 0

for i, listOfMinutes in enumerate(all_lectures):
    # for minute in listOfMinutes:
    # For each lecture
    total_lec_time_sec = 0
    for minute in listOfMinutes:
        min_num = int(minute)
        # print(min_num)
        sec_num = minute - min_num
        # print(int(sec_num*100))
        total_lec_time_sec += min_num*60 + int(sec_num*100)

    total_time += total_lec_time_sec/60

    print("Lec", i+1)
    print("Videos:", len(listOfMinutes))
    # print("Total seconds:", total_lec_time_sec)
    print("Minutes       :", total_lec_time_sec/60)
    print("Minutes (x1.5):", (total_lec_time_sec/60)*0.75)
    print("Minutes   (x2):", (total_lec_time_sec/60)*0.5)
    print("---------------------------")

print("Total lecture time       :", total_time, "min")
print("Total lecture time (x1.5):", total_time*0.75, "min")
print("Total lecture time   (x2):", total_time*0.5, "min")
# Out:
# Lec 1
# Videos: 8
# Minutes       : 101.56666666666666
# Minutes (x1.5): 76.175
# Minutes   (x2): 50.78333333333333
# ---------------------------
# Lec 2
# Videos: 8
# Minutes       : 136.55
# Minutes (x1.5): 102.41250000000001
# Minutes   (x2): 68.275
# ---------------------------
# Lec 3
# Videos: 6
# Minutes       : 97.91666666666667
# Minutes (x1.5): 73.4375
# Minutes   (x2): 48.958333333333336
# ---------------------------
# Lec 4
# Videos: 6
# Minutes       : 101.03333333333333
# Minutes (x1.5): 75.775
# Minutes   (x2): 50.516666666666666
# ---------------------------
# Lec 5
# Videos: 3
# Minutes       : 79.96666666666667
# Minutes (x1.5): 59.975
# Minutes   (x2): 39.983333333333334
# ---------------------------
# Lec 6
# Videos: 6
# Minutes       : 71.66666666666667
# Minutes (x1.5): 53.75
# Minutes   (x2): 35.833333333333336
# ---------------------------
# Lec 7
# Videos: 5
# Minutes       : 75.26666666666667
# Minutes (x1.5): 56.45
# Minutes   (x2): 37.63333333333333
# ...
